# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
data = pd.read_csv('/content/drive/MyDrive/AI GO/深度學習/traindataset加金門後/00traindata_all.csv ')
data
# Out:
#              ID  縣市      土地面積  移轉層次  總樓層數  主要用途  主要建材  建物型態         屋齡  \
# 0          TR-1   0 -0.256716    11    11     2     4     0  32.583333
# 1          TR-2   0  0.100134     7    12     2     4     0  24.166667
# 2          TR-3   6  0.181921    10    15    11     0     0   6.166667
# 3          TR-4   1  0.085594     9    14    11     4     0   8.833333
# 4          TR-5   1 -0.938116    41    43     2     5     0  11.000000
# ...         ...  ..       ...   ...   ...   ...   ...   ...        ...
# 11746  TR-11747   5  0.706189     4     5     2     4     1  28.333333
# 11747  TR-11748   2 -0.225809     2     7     2     4     2  29.250000
# 11748  TR-11749   1 -0.943908    15    17     2     4     0  22.833333
# 11749  TR-11750   1 -1.147111    12    16     2     4     0  25.083333
# 11750  TR-11751   1 -0.398154    11    27    11     5     0   2.250000
#
#            建物面積  ...  <0.5公車站數  與政府最短距  縣市_區域  與百貨最短距  <0.3公車站數     人口密度  \
# ...

# %%
data.dtypes
# Out:
# ID            object
# 縣市             int64
# 土地面積         float64
# 移轉層次           int64
# 總樓層數           int64
# 主要用途           int64
# 主要建材           int64
# 建物型態           int64
# 屋齡           float64
# 建物面積         float64
# 車位面積         float64
# 車位個數         float64
# 主建物面積        float64
# 陽台面積         float64
# 附屬建物面積       float64
# 單價           float64
# 經度           float64
# 緯度           float64
# 站點級別           int64
# 與大眾交通最短距     float64
# 與國小最短距       float64
# 國小總人數          int64
# 與國中最短距       float64
# 國中總人數          int64
# 與高中最短距       float64
# 高中總人數          int64
# 與大學最短距       float64
# 大學總人數          int64
# 與atm最短距      float64
# 與post最短距     float64
# 與bank最短距     float64
# 與腳踏車站最短距     float64
# 與醫療機構最短距     float64
# 與便利超商最短距     float64
# <0.5的超商數量      int64
# <0.5公車站數       int64
# 與政府最短距       float64
# 縣市_區域          int64
# 與百貨最短距       float64
# <0.3公車站數       int64
# 人口密度         float64
# 老化指數         float64
# 與高鐵最短距       float64
# ...

# %%
data[1:2]
# Out:
#      ID  縣市      土地面積  移轉層次  總樓層數  主要用途  主要建材  建物型態         屋齡      建物面積  ...  \
# 1  TR-2   0  0.100134     7    12     2     4     0  24.166667  0.314204  ...
#
#    <0.5公車站數  與政府最短距  縣市_區域  與百貨最短距  <0.3公車站數     人口密度   老化指數  與高鐵最短距      縱坐標  \
# 1        71    6.61     30    3.61        11  9126.87  166.1    3.53  2767990
#
#       橫坐標
# 1  300677
#
# [1 rows x 45 columns]

# %%
# 檢查資料的基本統計信息
print(data.describe())
# Out:
#                  縣市          土地面積          移轉層次          總樓層數          主要用途  \
# count  11751.000000  11751.000000  11751.000000  11751.000000  11751.000000
# mean       2.808867      0.018416      7.433665     12.602672      4.197515
# std        3.026222      1.072279      5.089029      6.840007      3.744824
# min        0.000000     -1.619755      2.000000      2.000000      0.000000
# 25%        1.000000     -0.646264      4.000000      7.000000      2.000000
# 50%        1.000000     -0.149839      6.000000     12.000000      2.000000
# 75%        5.000000      0.410167     10.000000     15.000000      5.000000
# max       17.000000     19.475175     46.000000     68.000000     11.000000
#
#                主要建材          建物型態            屋齡          建物面積          車位面積  \
# count  11751.000000  11751.000000  11751.000000  11751.000000  11751.000000
# mean       3.921028      0.576717     21.319058      0.030517      0.021030
# ...

# %%
# 使用isna()或isnull()方法檢查每個元素是否為缺失值，返回的是布林值
missing_values = data.isnull()

# 使用sum()方法計算每列的缺失值數量
missing_counts = missing_values.sum()

# 印出每列的缺失值數量
print(missing_counts)
# Out:
# ID           0
# 縣市           0
# 土地面積         0
# 移轉層次         0
# 總樓層數         0
# 主要用途         0
# 主要建材         0
# 建物型態         0
# 屋齡           0
# 建物面積         0
# 車位面積         0
# 車位個數         0
# 主建物面積        0
# 陽台面積         0
# 附屬建物面積       0
# 單價           0
# 經度           0
# 緯度           0
# 站點級別         0
# 與大眾交通最短距     0
# 與國小最短距       0
# 國小總人數        0
# 與國中最短距       0
# 國中總人數        0
# 與高中最短距       0
# 高中總人數        0
# 與大學最短距       0
# 大學總人數        0
# 與atm最短距      0
# 與post最短距     0
# 與bank最短距     0
# 與腳踏車站最短距     0
# 與醫療機構最短距     0
# 與便利超商最短距     0
# <0.5的超商數量    0
# <0.5公車站數     0
# 與政府最短距       0
# 縣市_區域        0
# 與百貨最短距       0
# <0.3公車站數     0
# 人口密度         0
# 老化指數         0
# 與高鐵最短距       0
# 縱坐標          0
# 橫坐標          0
# dtype: int64

# %%
# 計算特徵和目標的相關性
correlation = data.corrwith(data['單價'])

# 印出相關性結果
print(correlation)
# Out:
# 縣市          -0.580683
# 土地面積         0.067088
# 移轉層次         0.054038
# 總樓層數         0.037874
# 主要用途        -0.057103
# 主要建材         0.011903
# 建物型態         0.016075
# 屋齡           0.049196
# 建物面積         0.061327
# 車位面積         0.099986
# 車位個數         0.013064
# 主建物面積        0.056150
# 陽台面積         0.009866
# 附屬建物面積       0.064905
# 單價           1.000000
# 經度           0.456070
# 緯度           0.394313
# 站點級別        -0.276209
# 與大眾交通最短距    -0.322400
# 與國小最短距      -0.206658
# 國小總人數        0.062028
# 與國中最短距      -0.200208
# 國中總人數       -0.016664
# 與高中最短距      -0.287924
# 高中總人數       -0.101608
# 與大學最短距      -0.204057
# 大學總人數       -0.000158
# 與atm最短距     -0.143283
# 與post最短距    -0.230625
# 與bank最短距    -0.274789
# 與腳踏車站最短距    -0.083310
# 與醫療機構最短距    -0.165900
# 與便利超商最短距    -0.122501
# <0.5的超商數量    0.468489
# <0.5公車站數     0.485722
# 與政府最短距      -0.186859
# 縣市_區域       -0.443979
# 與百貨最短距      -0.284007
# <0.3公車站數     0.378012
# 人口密度         0.713742
# 老化指數         0.302304
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib

# %%
# 下載台北思源黑體並命名taipei_sans_tc_beta.ttf，移至指定路徑
# !wget -O TaipeiSansTCBeta-Regular.ttf https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_&export=download

import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.font_manager import fontManager

# 改style要在改font之前
# plt.style.use('seaborn')

fontManager.addfont('TaipeiSansTCBeta-Regular.ttf')
mpl.rc('font', family='Taipei Sans TC Beta')
# Out:
# --2023-11-09 09:03:59--  https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.google.com (drive.google.com)... 142.251.175.138, 142.251.175.101, 142.251.175.100, ...
# Connecting to drive.google.com (drive.google.com)|142.251.175.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0k-9o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/3ocuku3oerj5207nih42h9bo55rfdbg6/1699520625000/02847987870453524430/*/1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_?uuid=af9800a5-4b1c-4c95-82f9-76568e4e74aa [following]
# ...
# --2023-11-09 09:04:00--  https://doc-0k-9o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/3ocuku3oerj5207nih42h9bo55rfdbg6/1699520625000/02847987870453524430/*/1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_?uuid=af9800a5-4b1c-4c95-82f9-76568e4e74aa
# Resolving doc-0k-9o-docs.googleusercontent.com (doc-0k-9o-docs.googleusercontent.com)... 64.233.170.132, 2404:6800:4003:c1a::84
# ...

# %%
def scatter(column:str, df):
  sns.scatterplot(x=column, y='單價', data=df)
  plt.xlabel(column)
  plt.ylabel('單價')
  plt.savefig('/content/drive/MyDrive/AI GO/深度學習/相關性分析/{}.png'.format(column))
  plt.show()

# %%
scatter('土地面積', data)

# %%
data.columns
# Out:
# Index(['ID', '縣市', '土地面積', '移轉層次', '總樓層數', '主要用途', '主要建材', '建物型態', '屋齡',
#        '建物面積', '車位面積', '車位個數', '主建物面積', '陽台面積', '附屬建物面積', '單價', '經度', '緯度',
#        '站點級別', '與大眾交通最短距', '與國小最短距', '國小總人數', '與國中最短距', '國中總人數', '與高中最短距',
#        '高中總人數', '與大學最短距', '大學總人數', '與atm最短距', '與post最短距', '與bank最短距',
#        '與腳踏車站最短距', '與醫療機構最短距', '與便利超商最短距', '<0.5的超商數量', '<0.5公車站數', '與政府最短距',
#        '縣市_區域', '與百貨最短距', '<0.3公車站數', '人口密度', '老化指數', '與高鐵最短距', '縱坐標', '橫坐標'],
#       dtype='object')

# %%
temp = ['縣市', '土地面積', '移轉層次', '總樓層數', '主要用途', '主要建材', '建物型態', '屋齡',
       '建物面積', '車位面積', '車位個數', '主建物面積', '陽台面積', '附屬建物面積', '單價', '經度', '緯度',
       '站點級別', '與大眾交通最短距', '與國小最短距', '國小總人數', '與國中最短距', '國中總人數', '與高中最短距',
       '高中總人數', '與大學最短距', '大學總人數', '與atm最短距', '與post最短距', '與bank最短距',
       '與腳踏車站最短距', '與醫療機構最短距', '與便利超商最短距', '<0.5的超商數量', '<0.5公車站數', '與政府最短距',
       '縣市_區域', '與百貨最短距', '<0.3公車站數', '人口密度', '老化指數', '與高鐵最短距', '縱坐標', '橫坐標']

# %%
for i in temp:
  scatter(i, data)

# %%
temp_1 = ['縣市', '移轉層次', '總樓層數', '主要用途', '主要建材', '建物型態', '屋齡',
       '車位個數', '站點級別', '<0.5的超商數量', '<0.5公車站數', '縣市_區域', '<0.3公車站數']

# %%
def bar(column:str, df):
  sns.barplot(x=temp_1, y='單價', data=df, ci=95)
  plt.xlabel(column)
  plt.ylabel('單價')
  plt.savefig('/content/drive/MyDrive/AI GO/深度學習/相關性分析/{}-1.png'.format(column))
  plt.show()

# %%
for i in range(len(temp_1)):
  bar(temp_1[i], data)
# Out:
# <ipython-input-24-76d7919f8bcf>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.barplot(x=temp_1, y='單價', data=df, ci=95)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-252589771fdb> in <cell line: 1>()
#       1 for i in range(len(temp_1)):
# ----> 2   bar(temp_1[i], data)
#
# <ipython-input-24-76d7919f8bcf> in bar(column, df)
#       1 def bar(column:str, df):
# ----> 2   sns.barplot(x=temp_1, y='單價', data=df, ci=95)
#       3   plt.xlabel(column)
#       4   plt.ylabel('單價')
#       5   plt.savefig('/content/drive/MyDrive/AI GO/深度學習/相關性分析/{}-1.png'.format(column))
#
# ...

# %%
def bar(column:str, df):
  bar(temp_1, data)
  plt.xlabel(column)
  plt.ylabel('單價')
  plt.savefig('/content/drive/MyDrive/AI GO/深度學習/相關性分析/{}-2.png'.format(column))
  plt.show()

# %%
for i in range(len(temp_1)):
  scatter(temp_1[i], data)

# %%
# 檢查資料的基本統計信息
print(data['土地面積'].describe())
# Out:
# count    11751.000000
# mean         0.018416
# std          1.072279
# min         -1.619755
# 25%         -0.646264
# 50%         -0.149839
# 75%          0.410167
# max         19.475175
# Name: 土地面積, dtype: float64

# %%
data.loc[0]
# Out:
# ID                   TR-1
# 縣市                    台北市
# 鄉鎮市區                  大安區
# 路名                 敦化南路二段
# 土地面積            -0.256716
# 使用分區                 None
# 移轉層次                   11
# 總樓層數                   11
# 主要用途                  住家用
# 主要建材               鋼筋混凝土造
# 建物型態      住宅大樓(11層含以上有電梯)
# 屋齡              32.583333
# 建物面積            -0.174154
# 車位面積            -0.819326
# 車位個數                  0.0
# 橫坐標                305266
# 縱坐標               2768378
# 備註                    NaN
# 主建物面積            0.393926
# 陽台面積               0.1837
# 附屬建物面積          -0.438452
# 單價               4.627714
# Name: 0, dtype: object

# %%
data[0:1]['土地面積']
# Out:
# 0   -0.256716
# Name: 土地面積, dtype: float64

# %%
# 計算特徵和目標的相關性
correlation = data_no_outliers.corrwith(data['單價'])

# 印出相關性結果
print(correlation)
# Out:
# 土地面積      0.023702
# 移轉層次      0.045827
# 總樓層數      0.024308
# 屋齡        0.057960
# 建物面積      0.008680
# 車位面積      0.053349
# 車位個數     -0.019742
# 橫坐標       0.472450
# 縱坐標       0.409465
# 主建物面積     0.008331
# 陽台面積     -0.017626
# 附屬建物面積    0.065516
# 單價        1.000000
# dtype: float64
# <ipython-input-84-0522774a909f>:2: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = data_no_outliers.corrwith(data['單價'])

# %%
# 計算特徵和目標的相關性
correlation = data.corrwith(data['單價'])

# 印出相關性結果
print(correlation)
# Out:
# 土地面積      0.067088
# 移轉層次      0.054038
# 總樓層數      0.037874
# 屋齡        0.049196
# 建物面積      0.061327
# 車位面積      0.099986
# 車位個數      0.013064
# 橫坐標       0.455633
# 縱坐標       0.394402
# 主建物面積     0.056150
# 陽台面積      0.009866
# 附屬建物面積    0.064905
# 單價        1.000000
# dtype: float64
# <ipython-input-85-b84196a632bb>:2: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = data.corrwith(data['單價'])
